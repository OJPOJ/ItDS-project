# %% [markdown]
# # 1

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
import networkx as nx
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, classification_report 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
data = pd.read_csv('synthetic_data_lung_cancer.csv')
data.describe().T
# Out:
#                count        mean         std       min         25%  \
# SUBJECT_ID  560971.0  478.783759  274.017435  1.000000  242.000000
# TIME        560971.0    4.160220    2.372683  0.000001    2.166878
#
#                    50%        75%         max
# SUBJECT_ID  471.000000  701.00000  984.000000
# TIME          4.220659    6.15983   16.866712

# %%
sample_definition_ids = data['DEFINITION_ID'].drop_duplicates().sample(50, random_state=1)
sample_definition_ids.tolist()
# Out:
# ['procedure_235',
#  'observation_151',
#  'condition_1203',
#  'measurement_1024',
#  'condition_2200',
#  'condition_1057',
#  'condition_1870',
#  'condition_915',
#  'procedure_462',
#  'measurement_1220',
#  'observation_162',
#  'condition_204',
#  'drug_379',
#  'measurement_1160',
#  'measurement_1005',
#  'condition_1231',
#  'condition_840',
#  'measurement_1159',
#  'observation_122',
#  'measurement_411',
#  'condition_744',
#  'condition_1462',
#  'measurement_90',
#  'condition_455',
#  'condition_2179',
#  'measurement_478',
#  'measurement_64',
#  'observation_32',
#  'observation_7',
#  'condition_359',
#  'condition_2184',
#  'condition_322',
#  'procedure_372',
#  'condition_2291',
#  'procedure_254',
#  'measurement_667',
#  'condition_1052',
#  'procedure_137',
#  'measurement_896',
#  'drug_156',
#  'procedure_404',
#  'measurement_1034',
#  'measurement_962',
#  'condition_1966',
#  'condition_623',
#  'condition_1885',
#  'drug_277',
#  'procedure_84',
#  'condition_1815',
#  'condition_2345']

# %%
data['CATEGORY'] = data['DEFINITION_ID'].apply(lambda x: x.split('_')[0])
category_counts = data.groupby(['SUBJECT_ID', 'CATEGORY']).size().unstack(fill_value=0)
category_counts.head()
# Out:
# CATEGORY    condition  death  drug  measurement  observation  procedure
# SUBJECT_ID
# 1                 261      0   195           33           48         38
# 2                  95      1    45           88           78         57
# 3                 144      0    59          561           69         95
# 4                  30      1    11          385           22         50
# 6                  30      0     8          131           34         26

# %%
time_to_event = data.groupby('SUBJECT_ID')['TIME'].max()
cox_data = category_counts.merge(time_to_event, on='SUBJECT_ID')
cox_data['event'] = (cox_data['death'] > 0).astype(int)
cox_data = cox_data.drop(columns=['death'])
cox_data.head()
# Out:
#             condition  drug  measurement  observation  procedure      TIME  \
# SUBJECT_ID
# 1                 261   195           33           48         38  4.932455
# 2                  95    45           88           78         57  2.518113
# 3                 144    59          561           69         95  3.994337
# 4                  30    11          385           22         50  4.002734
# 6                  30     8          131           34         26  5.894177
#
#             event
# SUBJECT_ID
# 1               0
# 2               1
# 3               0
# 4               1
# 6               0

# %%
pip install lifelines
# Out:
# Requirement already satisfied: lifelines in c:\users\shaoci weng\anaconda3\lib\site-packages (0.27.8)
# Requirement already satisfied: numpy<2.0,>=1.14.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from lifelines) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from lifelines) (1.10.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from lifelines) (1.5.3)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from lifelines) (3.7.1)
# Requirement already satisfied: autograd>=1.5 in c:\users\shaoci weng\anaconda3\lib\site-packages (from lifelines) (1.6.2)
# Requirement already satisfied: autograd-gamma>=0.3 in c:\users\shaoci weng\anaconda3\lib\site-packages (from lifelines) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in c:\users\shaoci weng\anaconda3\lib\site-packages (from lifelines) (0.6.6)
# Requirement already satisfied: future>=0.15.2 in c:\users\shaoci weng\anaconda3\lib\site-packages (from autograd>=1.5->lifelines) (0.18.3)
# Requirement already satisfied: astor>=0.8 in c:\users\shaoci weng\anaconda3\lib\site-packages (from formulaic>=0.2.2->lifelines) (0.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from formulaic>=0.2.2->lifelines) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from formulaic>=0.2.2->lifelines) (4.7.1)
# Requirement already satisfied: wrapt>=1.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from formulaic>=0.2.2->lifelines) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shaoci weng\anaconda3\lib\site-packages (from matplotlib>=3.0->lifelines) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shaoci weng\anaconda3\lib\site-packages (from matplotlib>=3.0->lifelines) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from matplotlib>=3.0->lifelines) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shaoci weng\anaconda3\lib\site-packages (from matplotlib>=3.0->lifelines) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from matplotlib>=3.0->lifelines) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shaoci weng\anaconda3\lib\site-packages (from matplotlib>=3.0->lifelines) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shaoci weng\anaconda3\lib\site-packages (from matplotlib>=3.0->lifelines) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shaoci weng\anaconda3\lib\site-packages (from matplotlib>=3.0->lifelines) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shaoci weng\anaconda3\lib\site-packages (from pandas>=1.0.0->lifelines) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\shaoci weng\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from lifelines import CoxPHFitter
cox_model = CoxPHFitter()
cox_model.fit(cox_data, duration_col='TIME', event_col='event')
cox_model_summary = cox_model.summary
cox_model.summary
# Out:
#                  coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# covariate
# condition    0.004508   1.004518  0.001907        0.000771        0.008245
# drug        -0.006004   0.994014  0.002804       -0.011499       -0.000509
# measurement -0.003044   0.996961  0.000541       -0.004104       -0.001983
# observation -0.012518   0.987560  0.002761       -0.017929       -0.007107
# procedure   -0.002372   0.997631  0.003959       -0.010132        0.005388
#
#              exp(coef) lower 95%  exp(coef) upper 95%  cmp to         z  \
# covariate
# condition               1.000771             1.008280     0.0  2.364195
# drug                    0.988566             0.999491     0.0 -2.141628
# measurement             0.995904             0.998019     0.0 -5.625310
# observation             0.982230             0.992918     0.0 -4.534143
# procedure               0.989919             1.005403     0.0 -0.599070
#
#                         p   -log2(p)
# covariate
# condition    1.806929e-02   5.790317
# drug         3.222341e-02   4.955747
# measurement  1.851749e-08  25.686536
# observation  5.783777e-06  17.399557
# procedure    5.491265e-01   0.864789

# %%
from lifelines.utils import concordance_index
cox_data['risk_scores'] = cox_model.predict_partial_hazard(cox_data)
c_index = concordance_index(cox_data['TIME'], -cox_data['risk_scores'], cox_data['event'])
print(f"Concordance index: {c_index}")
# Out:
# Concordance index: 0.8473339870164999

# %%
cox_data.head()
# Out:
#             condition  drug  measurement  observation  procedure      TIME  \
# SUBJECT_ID
# 1                 261   195           33           48         38  4.932455
# 2                  95    45           88           78         57  2.518113
# 3                 144    59          561           69         95  3.994337
# 4                  30    11          385           22         50  4.002734
# 6                  30     8          131           34         26  5.894177
#
#             event  risk_scores
# SUBJECT_ID
# 1               0     3.982037
# 2               1     2.575569
# 3               0     0.715811
# 4               1     1.955731
# 6               0     3.930013

# %%
cox_data['death'] = cox_data['event']
cox_data = cox_data.drop(columns=['event'])

# %%
cox_data
# Out:
#             condition  drug  measurement  observation  procedure      TIME  \
# SUBJECT_ID
# 1                 261   195           33           48         38  4.932455
# 2                  95    45           88           78         57  2.518113
# 3                 144    59          561           69         95  3.994337
# 4                  30    11          385           22         50  4.002734
# 6                  30     8          131           34         26  5.894177
# ...               ...   ...          ...          ...        ...       ...
# 975                13     0           22            6          9  0.288566
# 976                11     0           63           14         29  0.273975
# 979                 2     0           62            1          0  0.094755
# 981                 4     0            1            6          7  3.149692
# 984                 5     0           46            6          6  0.038022
#
#             risk_scores  death
# SUBJECT_ID
# 1              3.982037      0
# 2              2.575569      1
# 3              0.715811      0
# 4              1.955731      1
# 6              3.930013      0
# ...                 ...    ...
# 975            7.866851      0
# 976            5.937313      0
# 979            7.208420      0
# 981            8.090989      1
# 984            7.103975      0
#
# [727 rows x 8 columns]
